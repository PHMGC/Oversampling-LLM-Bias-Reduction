# %% [markdown]
# ## Conclusion
#
# Here we summarize the key findings from our and Guilherme's experiments on various strategies to mitigate class imbalance bias in text classification tasks.
# We compare the performance of each strategy based on Macro-F1 and TPRGap metrics, and discuss the tradeoffs involved in their implementation.
